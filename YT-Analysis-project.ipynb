# %%
from yt_crawl import *

# %% [markdown]
# ## Function to get channel statistics
# ### Input your api_key

# %%
#AIzaSyC5hKNdZZmf-NRaugLsUBZjI9Mga2v3xkY
api_key = 'your api_key'
youtube = build('youtube', 'v3', developerKey=api_key)

# %%
channel_ids = ['UCZE88kYvCKUKjM-G0uc8Duw','UCAGikSCgqbeIXCvoXixWovQ']#khoa pug /khoai lang thang

channel_statistics = get_channel_stats(youtube, channel_ids)
channel_data = pd.DataFrame(channel_statistics)
channel_data['Subscribers'] = pd.to_numeric(channel_data['Subscribers'])
channel_data['Views'] = pd.to_numeric(channel_data['Views'])
channel_data['Total_videos'] = pd.to_numeric(channel_data['Total_videos'])
print(channel_data)
# Out:
#        Channel_name  Subscribers      Views  Total_videos  \
# 0          Khoa Pug      4460000  977611231           475
# 1  Khoai Lang Thang      1850000  371866012           216
#
#                 playlist_id
# 0  UUAGikSCgqbeIXCvoXixWovQ
# 1  UUZE88kYvCKUKjM-G0uc8Duw

# %% [markdown]
# ### đổi index để lọc các kênh khác

# %%
index=0
video_ids = get_video_ids(youtube, channel_data['playlist_id'][index])
video_ids_=pd.DataFrame(video_ids)
video_ids_.to_csv('video_ids.csv',header=['id'])

# %% [markdown]
# ### count1 đế save lại đã sử lý tới vid nào để lỡ có bị ngắt thì nó có thể tiếp tục được

# %%
video_ids=pd.read_csv('video_ids.csv')
with open('counter.txt','r') as f:
    count1=int(f.read())
    f.close()
video_ids=list(video_ids.values[count1:,1])
video_ids
count=len(os.listdir('content'))
print("processed",count1)
print("next_out",count)
video_details = get_video_details(youtube, video_ids,count,count1)

#success -set count=0
count1=0
write_count(count1,'counter.txt')
# Out:
# 0
# 64
# process vid 0 Sốc: Khoa Pug Cắt Bỏ Đuôi Tóc Nói Lời Chia Tay Cuối Cùng Sau 5 Năm Làm Youtube! :
# ['Tiếng Việt (được tạo tự động)']
# continue
# process vid 1 Nhà Hàng Nhật Hơn 100 Năm Sang Trọng Trên Đồi Hollywood! - Khoa Pug Ko Đỡ Nỗi Đồ Ăn Nhật Kiểu Mỹ! :
# ['Tiếng Việt (được tạo tự động)']
# continue
# process vid 2 Người Việt Đem Bò Kobe, Tôm Hùm Ra Bán Street Food Ở Mỹ! - Khoa Pug Bất Ngờ Street Food Ở Mỹ Và VN! :
# ['Tiếng Việt (được tạo tự động)']
# continue
# process vid 3 Khoa Pug Review Hàng Không Mẫu Hạm USS Midway - Tàu Sân Bay Chục Tỷ Đô! - Sức Mạnh Của Quân Đội Mỹ! :
# ['Tiếng Việt (được tạo tự động)']
# continue
# process vid 4 Hải Sản Hàn Quốc Nướng Than Hàng Hiếm Ở K-Town Mỹ! - Khoa Pug Qua Khu Hàn Quốc Chơi Squid Game! :
# ['Tiếng Việt (được tạo tự động)']
# continue
# process vid 5 Bị Chê Quá Khoa Pug Đi Cạo Đầu Xuyên Mỹ 4000km Trong 4 Ngày Từ New York - Los Angeles Thi Bằng Lái! :
# ['Tiếng Việt (được tạo tự động)']
# continue
# ...
